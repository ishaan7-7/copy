# %%
import sys
from pathlib import Path

PIPELINE_ROOT = Path(r"C:\streaming_emulator")

if str(PIPELINE_ROOT) not in sys.path:
    sys.path.insert(0, str(PIPELINE_ROOT))

print("sys.path[0]:", sys.path[0])
# Out:
# sys.path[0]: C:\streaming_emulator

# %%
from pathlib import Path
import json

PIPELINE_ROOT = Path(r"C:\streaming_emulator")
CONFIG_PATH = PIPELINE_ROOT / "replay" / "config" / "replay_config.json"

assert PIPELINE_ROOT.exists()
assert CONFIG_PATH.exists()

print("Pipeline root:", PIPELINE_ROOT)
print("Replay config:", CONFIG_PATH)
# Out:
# Pipeline root: C:\streaming_emulator
# Replay config: C:\streaming_emulator\replay\config\replay_config.json

# %%
with CONFIG_PATH.open("r", encoding="utf-8") as f:
    replay_config = json.load(f)

replay_config
# Out:
# {'enabled_sims': ['sim001',
#   'sim002',
#   'sim003',
#   'sim007',
#   'sim008',
#   'sim009',
#   'sim010'],
#  'replay_mode': 'fixed_rate',
#  'rows_per_second': 1,
#  'batch_size': 100,
#  'batch_interval_seconds': 5,
#  'http_endpoint': 'http://127.0.0.1:8000/ingest/v1/events',
#  'reset': {'enabled': False, 'archive_dlq': True}}

# %%
replay_config["enabled_sims"] = ["sim001", "sim002", "sim003", "sim007", "sim008", "sim009", "sim010"]
replay_config["replay_mode"] = "fixed_rate"
replay_config["rows_per_second"] = 1


replay_config["reset"] = {
    "enabled": False,
    "archive_dlq": True,
}

with CONFIG_PATH.open("w", encoding="utf-8") as f:
    json.dump(replay_config, f, indent=2)

print("Config updated.")
# Out:
# Config updated.

# %%
from replay.service.replay_service import ReplayService

service = ReplayService(
    pipeline_root=PIPELINE_ROOT,
    enabled_sims=replay_config.get("enabled_sims"),
    replay_mode=replay_config["replay_mode"],
    rows_per_second=replay_config.get("rows_per_second"),
    batch_interval_seconds=replay_config.get("batch_interval_seconds"),
    http_endpoint=replay_config["http_endpoint"],
)

service.start(
    reset=replay_config.get("reset", {}).get("enabled", False),
    archive_dlq=replay_config.get("reset", {}).get("archive_dlq", True),
)

print("Replay service started.")
# Out:
# Replay metrics server started on port 9001
# Replay service started.
# Exception in thread Thread-21 (_run_source):
# Traceback (most recent call last):
#   File "C:\streaming_emulator\replay\service\checkpoint.py", line 67, in save
#     tmp_path.replace(path)  # atomic on same filesystem
#     ~~~~~~~~~~~~~~~~^^^^^^
#   File "C:\Program Files\Python313\Lib\pathlib\_local.py", line 780, in replace
#     os.replace(self, target)
#     ~~~~~~~~~~^^^^^^^^^^^^^^
# PermissionError: [WinError 5] Access is denied: 'C:\\streaming_emulator\\replay\\checkpoints\\sim007_body.json.tmp' -> 'C:\\streaming_emulator\\replay\\checkpoints\\sim007_body.json'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Program Files\Python313\Lib\threading.py", line 1041, in _bootstrap_inner
#     self.run()
#     ~~~~~~~~^^
#   File "C:\Program Files\Python313\Lib\threading.py", line 992, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\streaming_emulator\replay\service\replay_service.py", line 77, in _run_source
#     run_worker(
#     ~~~~~~~~~~^
#         source=source,
#         ^^^^^^^^^^^^^^
#     ...<8 lines>...
#         batch_interval_seconds=self.batch_interval_seconds,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "C:\streaming_emulator\replay\service\worker.py", line 211, in run_worker
#     checkpoint_store.save(
#     ~~~~~~~~~~~~~~~~~~~~~^
#         source_id=source_id,
#         ^^^^^^^^^^^^^^^^^^^^
#         last_row_index=row_index,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^
#         last_row_hash=row_hash,
#         ^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "C:\streaming_emulator\replay\service\checkpoint.py", line 69, in save
#     raise CheckpointError(
#         f"Failed to write checkpoint for {source_id}"
#     ) from e
# replay.service.checkpoint.CheckpointError: Failed to write checkpoint for sim007_body
# Exception in thread Thread-38 (_run_source):
# Traceback (most recent call last):
#   File "C:\streaming_emulator\replay\service\checkpoint.py", line 67, in save
#     tmp_path.replace(path)  # atomic on same filesystem
#     ~~~~~~~~~~~~~~~~^^^^^^
#   File "C:\Program Files\Python313\Lib\pathlib\_local.py", line 780, in replace
#     os.replace(self, target)
#     ~~~~~~~~~~^^^^^^^^^^^^^^
# PermissionError: [WinError 5] Access is denied: 'C:\\streaming_emulator\\replay\\checkpoints\\sim010_tyre.json.tmp' -> 'C:\\streaming_emulator\\replay\\checkpoints\\sim010_tyre.json'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Program Files\Python313\Lib\threading.py", line 1041, in _bootstrap_inner
#     self.run()
#     ~~~~~~~~^^
#   File "C:\Program Files\Python313\Lib\threading.py", line 992, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\streaming_emulator\replay\service\replay_service.py", line 77, in _run_source
#     run_worker(
#     ~~~~~~~~~~^
#         source=source,
#         ^^^^^^^^^^^^^^
#     ...<8 lines>...
#         batch_interval_seconds=self.batch_interval_seconds,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "C:\streaming_emulator\replay\service\worker.py", line 211, in run_worker
#     checkpoint_store.save(
#     ~~~~~~~~~~~~~~~~~~~~~^
#         source_id=source_id,
#         ^^^^^^^^^^^^^^^^^^^^
#         last_row_index=row_index,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^
#         last_row_hash=row_hash,
#         ^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "C:\streaming_emulator\replay\service\checkpoint.py", line 69, in save
#     raise CheckpointError(
#         f"Failed to write checkpoint for {source_id}"
#     ) from e
# replay.service.checkpoint.CheckpointError: Failed to write checkpoint for sim010_tyre
# Exception in thread Thread-6 (_run_source):
# Traceback (most recent call last):
#   File "C:\streaming_emulator\replay\service\checkpoint.py", line 67, in save
#     tmp_path.replace(path)  # atomic on same filesystem
#     ~~~~~~~~~~~~~~~~^^^^^^
#   File "C:\Program Files\Python313\Lib\pathlib\_local.py", line 780, in replace
#     os.replace(self, target)
#     ~~~~~~~~~~^^^^^^^^^^^^^^
# PermissionError: [WinError 5] Access is denied: 'C:\\streaming_emulator\\replay\\checkpoints\\sim001_body.json.tmp' -> 'C:\\streaming_emulator\\replay\\checkpoints\\sim001_body.json'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Program Files\Python313\Lib\threading.py", line 1041, in _bootstrap_inner
#     self.run()
#     ~~~~~~~~^^
#   File "C:\Program Files\Python313\Lib\threading.py", line 992, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\streaming_emulator\replay\service\replay_service.py", line 77, in _run_source
#     run_worker(
#     ~~~~~~~~~~^
#         source=source,
#         ^^^^^^^^^^^^^^
#     ...<8 lines>...
#         batch_interval_seconds=self.batch_interval_seconds,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "C:\streaming_emulator\replay\service\worker.py", line 211, in run_worker
#     checkpoint_store.save(
#     ~~~~~~~~~~~~~~~~~~~~~^
#         source_id=source_id,
#         ^^^^^^^^^^^^^^^^^^^^
#         last_row_index=row_index,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^
#         last_row_hash=row_hash,
#         ^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "C:\streaming_emulator\replay\service\checkpoint.py", line 69, in save
#     raise CheckpointError(
#         f"Failed to write checkpoint for {source_id}"
#     ) from e
# replay.service.checkpoint.CheckpointError: Failed to write checkpoint for sim001_body
# Exception in thread Thread-37 (_run_source):
# Traceback (most recent call last):
#   File "C:\streaming_emulator\replay\service\checkpoint.py", line 67, in save
#     tmp_path.replace(path)  # atomic on same filesystem
#     ~~~~~~~~~~~~~~~~^^^^^^
#   File "C:\Program Files\Python313\Lib\pathlib\_local.py", line 780, in replace
#     os.replace(self, target)
#     ~~~~~~~~~~^^^^^^^^^^^^^^
# PermissionError: [WinError 5] Access is denied: 'C:\\streaming_emulator\\replay\\checkpoints\\sim010_transmission.json.tmp' -> 'C:\\streaming_emulator\\replay\\checkpoints\\sim010_transmission.json'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Program Files\Python313\Lib\threading.py", line 1041, in _bootstrap_inner
#     self.run()
#     ~~~~~~~~^^
#   File "C:\Program Files\Python313\Lib\threading.py", line 992, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\streaming_emulator\replay\service\replay_service.py", line 77, in _run_source
#     run_worker(
#     ~~~~~~~~~~^
#         source=source,
#         ^^^^^^^^^^^^^^
#     ...<8 lines>...
#         batch_interval_seconds=self.batch_interval_seconds,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "C:\streaming_emulator\replay\service\worker.py", line 211, in run_worker
#     checkpoint_store.save(
#     ~~~~~~~~~~~~~~~~~~~~~^
#         source_id=source_id,
#         ^^^^^^^^^^^^^^^^^^^^
#         last_row_index=row_index,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^
#         last_row_hash=row_hash,
#         ^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "C:\streaming_emulator\replay\service\checkpoint.py", line 69, in save
#     raise CheckpointError(
#         f"Failed to write checkpoint for {source_id}"
#     ) from e
# replay.service.checkpoint.CheckpointError: Failed to write checkpoint for sim010_transmission
# Exception in thread Thread-36 (_run_source):
# Traceback (most recent call last):
#   File "C:\streaming_emulator\replay\service\checkpoint.py", line 67, in save
#     tmp_path.replace(path)  # atomic on same filesystem
#     ~~~~~~~~~~~~~~~~^^^^^^
#   File "C:\Program Files\Python313\Lib\pathlib\_local.py", line 780, in replace
#     os.replace(self, target)
#     ~~~~~~~~~~^^^^^^^^^^^^^^
# PermissionError: [WinError 5] Access is denied: 'C:\\streaming_emulator\\replay\\checkpoints\\sim010_body.json.tmp' -> 'C:\\streaming_emulator\\replay\\checkpoints\\sim010_body.json'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Program Files\Python313\Lib\threading.py", line 1041, in _bootstrap_inner
#     self.run()
#     ~~~~~~~~^^
#   File "C:\Program Files\Python313\Lib\threading.py", line 992, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\streaming_emulator\replay\service\replay_service.py", line 77, in _run_source
#     run_worker(
#     ~~~~~~~~~~^
#         source=source,
#         ^^^^^^^^^^^^^^
#     ...<8 lines>...
#         batch_interval_seconds=self.batch_interval_seconds,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "C:\streaming_emulator\replay\service\worker.py", line 211, in run_worker
#     checkpoint_store.save(
#     ~~~~~~~~~~~~~~~~~~~~~^
#         source_id=source_id,
#         ^^^^^^^^^^^^^^^^^^^^
#         last_row_index=row_index,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^
#         last_row_hash=row_hash,
#         ^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "C:\streaming_emulator\replay\service\checkpoint.py", line 69, in save
#     raise CheckpointError(
#         f"Failed to write checkpoint for {source_id}"
#     ) from e
# replay.service.checkpoint.CheckpointError: Failed to write checkpoint for sim010_body
# Exception in thread Thread-25 (_run_source):
# Traceback (most recent call last):
#   File "C:\streaming_emulator\replay\service\checkpoint.py", line 67, in save
#     tmp_path.replace(path)  # atomic on same filesystem
#     ~~~~~~~~~~~~~~~~^^^^^^
#   File "C:\Program Files\Python313\Lib\pathlib\_local.py", line 780, in replace
#     os.replace(self, target)
#     ~~~~~~~~~~^^^^^^^^^^^^^^
# PermissionError: [WinError 5] Access is denied: 'C:\\streaming_emulator\\replay\\checkpoints\\sim008_battery.json.tmp' -> 'C:\\streaming_emulator\\replay\\checkpoints\\sim008_battery.json'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Program Files\Python313\Lib\threading.py", line 1041, in _bootstrap_inner
#     self.run()
#     ~~~~~~~~^^
#   File "C:\Program Files\Python313\Lib\threading.py", line 992, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\streaming_emulator\replay\service\replay_service.py", line 77, in _run_source
#     run_worker(
#     ~~~~~~~~~~^
#         source=source,
#         ^^^^^^^^^^^^^^
#     ...<8 lines>...
#         batch_interval_seconds=self.batch_interval_seconds,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "C:\streaming_emulator\replay\service\worker.py", line 211, in run_worker
#     checkpoint_store.save(
#     ~~~~~~~~~~~~~~~~~~~~~^
#         source_id=source_id,
#         ^^^^^^^^^^^^^^^^^^^^
#         last_row_index=row_index,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^
#         last_row_hash=row_hash,
#         ^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "C:\streaming_emulator\replay\service\checkpoint.py", line 69, in save
#     raise CheckpointError(
#         f"Failed to write checkpoint for {source_id}"
#     ) from e
# replay.service.checkpoint.CheckpointError: Failed to write checkpoint for sim008_battery
# Exception in thread Thread-26 (_run_source):
# Traceback (most recent call last):
#   File "C:\streaming_emulator\replay\service\checkpoint.py", line 67, in save
#     tmp_path.replace(path)  # atomic on same filesystem
#     ~~~~~~~~~~~~~~~~^^^^^^
#   File "C:\Program Files\Python313\Lib\pathlib\_local.py", line 780, in replace
#     os.replace(self, target)
#     ~~~~~~~~~~^^^^^^^^^^^^^^
# PermissionError: [WinError 5] Access is denied: 'C:\\streaming_emulator\\replay\\checkpoints\\sim008_body.json.tmp' -> 'C:\\streaming_emulator\\replay\\checkpoints\\sim008_body.json'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Program Files\Python313\Lib\threading.py", line 1041, in _bootstrap_inner
#     self.run()
#     ~~~~~~~~^^
#   File "C:\Program Files\Python313\Lib\threading.py", line 992, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\streaming_emulator\replay\service\replay_service.py", line 77, in _run_source
#     run_worker(
#     ~~~~~~~~~~^
#         source=source,
#         ^^^^^^^^^^^^^^
#     ...<8 lines>...
#         batch_interval_seconds=self.batch_interval_seconds,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "C:\streaming_emulator\replay\service\worker.py", line 211, in run_worker
#     checkpoint_store.save(
#     ~~~~~~~~~~~~~~~~~~~~~^
#         source_id=source_id,
#         ^^^^^^^^^^^^^^^^^^^^
#         last_row_index=row_index,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^
#         last_row_hash=row_hash,
#         ^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "C:\streaming_emulator\replay\service\checkpoint.py", line 69, in save
#     raise CheckpointError(
#         f"Failed to write checkpoint for {source_id}"
#     ) from e
# replay.service.checkpoint.CheckpointError: Failed to write checkpoint for sim008_body
# Exception in thread Thread-32 (_run_source):
# Traceback (most recent call last):
#   File "C:\streaming_emulator\replay\service\checkpoint.py", line 67, in save
#     tmp_path.replace(path)  # atomic on same filesystem
#     ~~~~~~~~~~~~~~~~^^^^^^
#   File "C:\Program Files\Python313\Lib\pathlib\_local.py", line 780, in replace
#     os.replace(self, target)
#     ~~~~~~~~~~^^^^^^^^^^^^^^
# PermissionError: [WinError 5] Access is denied: 'C:\\streaming_emulator\\replay\\checkpoints\\sim009_transmission.json.tmp' -> 'C:\\streaming_emulator\\replay\\checkpoints\\sim009_transmission.json'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Program Files\Python313\Lib\threading.py", line 1041, in _bootstrap_inner
#     self.run()
#     ~~~~~~~~^^
#   File "C:\Program Files\Python313\Lib\threading.py", line 992, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\streaming_emulator\replay\service\replay_service.py", line 77, in _run_source
#     run_worker(
#     ~~~~~~~~~~^
#         source=source,
#         ^^^^^^^^^^^^^^
#     ...<8 lines>...
#         batch_interval_seconds=self.batch_interval_seconds,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "C:\streaming_emulator\replay\service\worker.py", line 211, in run_worker
#     checkpoint_store.save(
#     ~~~~~~~~~~~~~~~~~~~~~^
#         source_id=source_id,
#         ^^^^^^^^^^^^^^^^^^^^
#         last_row_index=row_index,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^
#         last_row_hash=row_hash,
#         ^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "C:\streaming_emulator\replay\service\checkpoint.py", line 69, in save
#     raise CheckpointError(
#         f"Failed to write checkpoint for {source_id}"
#     ) from e
# replay.service.checkpoint.CheckpointError: Failed to write checkpoint for sim009_transmission
# Exception in thread Thread-16 (_run_source):
# Traceback (most recent call last):
#   File "C:\streaming_emulator\replay\service\checkpoint.py", line 67, in save
#     tmp_path.replace(path)  # atomic on same filesystem
#     ~~~~~~~~~~~~~~~~^^^^^^
#   File "C:\Program Files\Python313\Lib\pathlib\_local.py", line 780, in replace
#     os.replace(self, target)
#     ~~~~~~~~~~^^^^^^^^^^^^^^
# PermissionError: [WinError 5] Access is denied: 'C:\\streaming_emulator\\replay\\checkpoints\\sim003_body.json.tmp' -> 'C:\\streaming_emulator\\replay\\checkpoints\\sim003_body.json'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Program Files\Python313\Lib\threading.py", line 1041, in _bootstrap_inner
#     self.run()
#     ~~~~~~~~^^
#   File "C:\Program Files\Python313\Lib\threading.py", line 992, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\streaming_emulator\replay\service\replay_service.py", line 77, in _run_source
#     run_worker(
#     ~~~~~~~~~~^
#         source=source,
#         ^^^^^^^^^^^^^^
#     ...<8 lines>...
#         batch_interval_seconds=self.batch_interval_seconds,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "C:\streaming_emulator\replay\service\worker.py", line 211, in run_worker
#     checkpoint_store.save(
#     ~~~~~~~~~~~~~~~~~~~~~^
#         source_id=source_id,
#         ^^^^^^^^^^^^^^^^^^^^
#         last_row_index=row_index,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^
#         last_row_hash=row_hash,
#         ^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "C:\streaming_emulator\replay\service\checkpoint.py", line 69, in save
#     raise CheckpointError(
#         f"Failed to write checkpoint for {source_id}"
#     ) from e
# replay.service.checkpoint.CheckpointError: Failed to write checkpoint for sim003_body
# Exception in thread Thread-33 (_run_source):
# Traceback (most recent call last):
#   File "C:\streaming_emulator\replay\service\checkpoint.py", line 67, in save
#     tmp_path.replace(path)  # atomic on same filesystem
#     ~~~~~~~~~~~~~~~~^^^^^^
#   File "C:\Program Files\Python313\Lib\pathlib\_local.py", line 780, in replace
#     os.replace(self, target)
#     ~~~~~~~~~~^^^^^^^^^^^^^^
# PermissionError: [WinError 5] Access is denied: 'C:\\streaming_emulator\\replay\\checkpoints\\sim009_tyre.json.tmp' -> 'C:\\streaming_emulator\\replay\\checkpoints\\sim009_tyre.json'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Program Files\Python313\Lib\threading.py", line 1041, in _bootstrap_inner
#     self.run()
#     ~~~~~~~~^^
#   File "C:\Program Files\Python313\Lib\threading.py", line 992, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\streaming_emulator\replay\service\replay_service.py", line 77, in _run_source
#     run_worker(
#     ~~~~~~~~~~^
#         source=source,
#         ^^^^^^^^^^^^^^
#     ...<8 lines>...
#         batch_interval_seconds=self.batch_interval_seconds,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "C:\streaming_emulator\replay\service\worker.py", line 211, in run_worker
#     checkpoint_store.save(
#     ~~~~~~~~~~~~~~~~~~~~~^
#         source_id=source_id,
#         ^^^^^^^^^^^^^^^^^^^^
#         last_row_index=row_index,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^
#         last_row_hash=row_hash,
#         ^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "C:\streaming_emulator\replay\service\checkpoint.py", line 69, in save
#     raise CheckpointError(
#         f"Failed to write checkpoint for {source_id}"
#     ) from e
# replay.service.checkpoint.CheckpointError: Failed to write checkpoint for sim009_tyre
# Exception in thread Thread-13 (_run_source):
# Traceback (most recent call last):
#   File "C:\streaming_emulator\replay\service\checkpoint.py", line 67, in save
#     tmp_path.replace(path)  # atomic on same filesystem
#     ~~~~~~~~~~~~~~~~^^^^^^
#   File "C:\Program Files\Python313\Lib\pathlib\_local.py", line 780, in replace
#     os.replace(self, target)
#     ~~~~~~~~~~^^^^^^^^^^^^^^
# PermissionError: [WinError 5] Access is denied: 'C:\\streaming_emulator\\replay\\checkpoints\\sim002_tyre.json.tmp' -> 'C:\\streaming_emulator\\replay\\checkpoints\\sim002_tyre.json'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Program Files\Python313\Lib\threading.py", line 1041, in _bootstrap_inner
#     self.run()
#     ~~~~~~~~^^
#   File "C:\Program Files\Python313\Lib\threading.py", line 992, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\streaming_emulator\replay\service\replay_service.py", line 77, in _run_source
#     run_worker(
#     ~~~~~~~~~~^
#         source=source,
#         ^^^^^^^^^^^^^^
#     ...<8 lines>...
#         batch_interval_seconds=self.batch_interval_seconds,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "C:\streaming_emulator\replay\service\worker.py", line 211, in run_worker
#     checkpoint_store.save(
#     ~~~~~~~~~~~~~~~~~~~~~^
#         source_id=source_id,
#         ^^^^^^^^^^^^^^^^^^^^
#         last_row_index=row_index,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^
#         last_row_hash=row_hash,
#         ^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "C:\streaming_emulator\replay\service\checkpoint.py", line 69, in save
#     raise CheckpointError(
#         f"Failed to write checkpoint for {source_id}"
#     ) from e
# replay.service.checkpoint.CheckpointError: Failed to write checkpoint for sim002_tyre
# Exception in thread Thread-19 (_run_source):
# Traceback (most recent call last):
#   File "C:\streaming_emulator\replay\service\checkpoint.py", line 67, in save
#     tmp_path.replace(path)  # atomic on same filesystem
#     ~~~~~~~~~~~~~~~~^^^^^^
#   File "C:\Program Files\Python313\Lib\pathlib\_local.py", line 780, in replace
#     os.replace(self, target)
#     ~~~~~~~~~~^^^^^^^^^^^^^^
# PermissionError: [WinError 5] Access is denied: 'C:\\streaming_emulator\\replay\\checkpoints\\sim007_engine.json.tmp' -> 'C:\\streaming_emulator\\replay\\checkpoints\\sim007_engine.json'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Program Files\Python313\Lib\threading.py", line 1041, in _bootstrap_inner
#     self.run()
#     ~~~~~~~~^^
#   File "C:\Program Files\Python313\Lib\threading.py", line 992, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\streaming_emulator\replay\service\replay_service.py", line 77, in _run_source
#     run_worker(
#     ~~~~~~~~~~^
#         source=source,
#         ^^^^^^^^^^^^^^
#     ...<8 lines>...
#         batch_interval_seconds=self.batch_interval_seconds,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "C:\streaming_emulator\replay\service\worker.py", line 211, in run_worker
#     checkpoint_store.save(
#     ~~~~~~~~~~~~~~~~~~~~~^
#         source_id=source_id,
#         ^^^^^^^^^^^^^^^^^^^^
#         last_row_index=row_index,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^
#         last_row_hash=row_hash,
#         ^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "C:\streaming_emulator\replay\service\checkpoint.py", line 69, in save
#     raise CheckpointError(
#         f"Failed to write checkpoint for {source_id}"
#     ) from e
# replay.service.checkpoint.CheckpointError: Failed to write checkpoint for sim007_engine
# Exception in thread Thread-29 (_run_source):
# Traceback (most recent call last):
#   File "C:\streaming_emulator\replay\service\checkpoint.py", line 67, in save
#     tmp_path.replace(path)  # atomic on same filesystem
#     ~~~~~~~~~~~~~~~~^^^^^^
#   File "C:\Program Files\Python313\Lib\pathlib\_local.py", line 780, in replace
#     os.replace(self, target)
#     ~~~~~~~~~~^^^^^^^^^^^^^^
# PermissionError: [WinError 5] Access is denied: 'C:\\streaming_emulator\\replay\\checkpoints\\sim009_engine.json.tmp' -> 'C:\\streaming_emulator\\replay\\checkpoints\\sim009_engine.json'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Program Files\Python313\Lib\threading.py", line 1041, in _bootstrap_inner
#     self.run()
#     ~~~~~~~~^^
#   File "C:\Program Files\Python313\Lib\threading.py", line 992, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\streaming_emulator\replay\service\replay_service.py", line 77, in _run_source
#     run_worker(
#     ~~~~~~~~~~^
#         source=source,
#         ^^^^^^^^^^^^^^
#     ...<8 lines>...
#         batch_interval_seconds=self.batch_interval_seconds,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "C:\streaming_emulator\replay\service\worker.py", line 211, in run_worker
#     checkpoint_store.save(
#     ~~~~~~~~~~~~~~~~~~~~~^
#         source_id=source_id,
#         ^^^^^^^^^^^^^^^^^^^^
#         last_row_index=row_index,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^
#         last_row_hash=row_hash,
#         ^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "C:\streaming_emulator\replay\service\checkpoint.py", line 69, in save
#     raise CheckpointError(
#         f"Failed to write checkpoint for {source_id}"
#     ) from e
# replay.service.checkpoint.CheckpointError: Failed to write checkpoint for sim009_engine
# Exception in thread Thread-14 (_run_source):
# Traceback (most recent call last):
#   File "C:\streaming_emulator\replay\service\checkpoint.py", line 67, in save
#     tmp_path.replace(path)  # atomic on same filesystem
#     ~~~~~~~~~~~~~~~~^^^^^^
#   File "C:\Program Files\Python313\Lib\pathlib\_local.py", line 780, in replace
#     os.replace(self, target)
#     ~~~~~~~~~~^^^^^^^^^^^^^^
# PermissionError: [WinError 5] Access is denied: 'C:\\streaming_emulator\\replay\\checkpoints\\sim003_engine.json.tmp' -> 'C:\\streaming_emulator\\replay\\checkpoints\\sim003_engine.json'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Program Files\Python313\Lib\threading.py", line 1041, in _bootstrap_inner
#     self.run()
#     ~~~~~~~~^^
#   File "C:\Program Files\Python313\Lib\threading.py", line 992, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\streaming_emulator\replay\service\replay_service.py", line 77, in _run_source
#     run_worker(
#     ~~~~~~~~~~^
#         source=source,
#         ^^^^^^^^^^^^^^
#     ...<8 lines>...
#         batch_interval_seconds=self.batch_interval_seconds,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "C:\streaming_emulator\replay\service\worker.py", line 211, in run_worker
#     checkpoint_store.save(
#     ~~~~~~~~~~~~~~~~~~~~~^
#         source_id=source_id,
#         ^^^^^^^^^^^^^^^^^^^^
#         last_row_index=row_index,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^
#         last_row_hash=row_hash,
#         ^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "C:\streaming_emulator\replay\service\checkpoint.py", line 69, in save
#     raise CheckpointError(
#         f"Failed to write checkpoint for {source_id}"
#     ) from e
# replay.service.checkpoint.CheckpointError: Failed to write checkpoint for sim003_engine
# Exception in thread Thread-15 (_run_source):
# Traceback (most recent call last):
#   File "C:\streaming_emulator\replay\service\checkpoint.py", line 67, in save
#     tmp_path.replace(path)  # atomic on same filesystem
#     ~~~~~~~~~~~~~~~~^^^^^^
#   File "C:\Program Files\Python313\Lib\pathlib\_local.py", line 780, in replace
#     os.replace(self, target)
#     ~~~~~~~~~~^^^^^^^^^^^^^^
# PermissionError: [WinError 5] Access is denied: 'C:\\streaming_emulator\\replay\\checkpoints\\sim003_battery.json.tmp' -> 'C:\\streaming_emulator\\replay\\checkpoints\\sim003_battery.json'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Program Files\Python313\Lib\threading.py", line 1041, in _bootstrap_inner
#     self.run()
#     ~~~~~~~~^^
#   File "C:\Program Files\Python313\Lib\threading.py", line 992, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\streaming_emulator\replay\service\replay_service.py", line 77, in _run_source
#     run_worker(
#     ~~~~~~~~~~^
#         source=source,
#         ^^^^^^^^^^^^^^
#     ...<8 lines>...
#         batch_interval_seconds=self.batch_interval_seconds,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "C:\streaming_emulator\replay\service\worker.py", line 211, in run_worker
#     checkpoint_store.save(
#     ~~~~~~~~~~~~~~~~~~~~~^
#         source_id=source_id,
#         ^^^^^^^^^^^^^^^^^^^^
#         last_row_index=row_index,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^
#         last_row_hash=row_hash,
#         ^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "C:\streaming_emulator\replay\service\checkpoint.py", line 69, in save
#     raise CheckpointError(
#         f"Failed to write checkpoint for {source_id}"
#     ) from e
# replay.service.checkpoint.CheckpointError: Failed to write checkpoint for sim003_battery
# Exception in thread Thread-5 (_run_source):
# Traceback (most recent call last):
#   File "C:\streaming_emulator\replay\service\checkpoint.py", line 67, in save
#     tmp_path.replace(path)  # atomic on same filesystem
#     ~~~~~~~~~~~~~~~~^^^^^^
#   File "C:\Program Files\Python313\Lib\pathlib\_local.py", line 780, in replace
#     os.replace(self, target)
#     ~~~~~~~~~~^^^^^^^^^^^^^^
# PermissionError: [WinError 5] Access is denied: 'C:\\streaming_emulator\\replay\\checkpoints\\sim001_battery.json.tmp' -> 'C:\\streaming_emulator\\replay\\checkpoints\\sim001_battery.json'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Program Files\Python313\Lib\threading.py", line 1041, in _bootstrap_inner
#     self.run()
#     ~~~~~~~~^^
#   File "C:\Program Files\Python313\Lib\threading.py", line 992, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\streaming_emulator\replay\service\replay_service.py", line 77, in _run_source
#     run_worker(
#     ~~~~~~~~~~^
#         source=source,
#         ^^^^^^^^^^^^^^
#     ...<8 lines>...
#         batch_interval_seconds=self.batch_interval_seconds,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "C:\streaming_emulator\replay\service\worker.py", line 211, in run_worker
#     checkpoint_store.save(
#     ~~~~~~~~~~~~~~~~~~~~~^
#         source_id=source_id,
#         ^^^^^^^^^^^^^^^^^^^^
#         last_row_index=row_index,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^
#         last_row_hash=row_hash,
#         ^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "C:\streaming_emulator\replay\service\checkpoint.py", line 69, in save
#     raise CheckpointError(
#         f"Failed to write checkpoint for {source_id}"
#     ) from e
# replay.service.checkpoint.CheckpointError: Failed to write checkpoint for sim001_battery
# Exception in thread Thread-4 (_run_source):
# Traceback (most recent call last):
#   File "C:\streaming_emulator\replay\service\checkpoint.py", line 67, in save
#     tmp_path.replace(path)  # atomic on same filesystem
#     ~~~~~~~~~~~~~~~~^^^^^^
#   File "C:\Program Files\Python313\Lib\pathlib\_local.py", line 780, in replace
#     os.replace(self, target)
#     ~~~~~~~~~~^^^^^^^^^^^^^^
# PermissionError: [WinError 5] Access is denied: 'C:\\streaming_emulator\\replay\\checkpoints\\sim001_engine.json.tmp' -> 'C:\\streaming_emulator\\replay\\checkpoints\\sim001_engine.json'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Program Files\Python313\Lib\threading.py", line 1041, in _bootstrap_inner
#     self.run()
#     ~~~~~~~~^^
#   File "C:\Program Files\Python313\Lib\threading.py", line 992, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\streaming_emulator\replay\service\replay_service.py", line 77, in _run_source
#     run_worker(
#     ~~~~~~~~~~^
#         source=source,
#         ^^^^^^^^^^^^^^
#     ...<8 lines>...
#         batch_interval_seconds=self.batch_interval_seconds,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "C:\streaming_emulator\replay\service\worker.py", line 211, in run_worker
#     checkpoint_store.save(
#     ~~~~~~~~~~~~~~~~~~~~~^
#         source_id=source_id,
#         ^^^^^^^^^^^^^^^^^^^^
#         last_row_index=row_index,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^
#         last_row_hash=row_hash,
#         ^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "C:\streaming_emulator\replay\service\checkpoint.py", line 69, in save
#     raise CheckpointError(
#         f"Failed to write checkpoint for {source_id}"
#     ) from e
# replay.service.checkpoint.CheckpointError: Failed to write checkpoint for sim001_engine
# Exception in thread Thread-10 (_run_source):
# Traceback (most recent call last):
#   File "C:\streaming_emulator\replay\service\checkpoint.py", line 67, in save
#     tmp_path.replace(path)  # atomic on same filesystem
#     ~~~~~~~~~~~~~~~~^^^^^^
#   File "C:\Program Files\Python313\Lib\pathlib\_local.py", line 780, in replace
#     os.replace(self, target)
#     ~~~~~~~~~~^^^^^^^^^^^^^^
# PermissionError: [WinError 5] Access is denied: 'C:\\streaming_emulator\\replay\\checkpoints\\sim002_battery.json.tmp' -> 'C:\\streaming_emulator\\replay\\checkpoints\\sim002_battery.json'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Program Files\Python313\Lib\threading.py", line 1041, in _bootstrap_inner
#     self.run()
#     ~~~~~~~~^^
#   File "C:\Program Files\Python313\Lib\threading.py", line 992, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\streaming_emulator\replay\service\replay_service.py", line 77, in _run_source
#     run_worker(
#     ~~~~~~~~~~^
#         source=source,
#         ^^^^^^^^^^^^^^
#     ...<8 lines>...
#         batch_interval_seconds=self.batch_interval_seconds,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "C:\streaming_emulator\replay\service\worker.py", line 211, in run_worker
#     checkpoint_store.save(
#     ~~~~~~~~~~~~~~~~~~~~~^
#         source_id=source_id,
#         ^^^^^^^^^^^^^^^^^^^^
#         last_row_index=row_index,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^
#         last_row_hash=row_hash,
#         ^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "C:\streaming_emulator\replay\service\checkpoint.py", line 69, in save
#     raise CheckpointError(
#         f"Failed to write checkpoint for {source_id}"
#     ) from e
# replay.service.checkpoint.CheckpointError: Failed to write checkpoint for sim002_battery
# Exception in thread Thread-8 (_run_source):
# Traceback (most recent call last):
#   File "C:\streaming_emulator\replay\service\checkpoint.py", line 67, in save
#     tmp_path.replace(path)  # atomic on same filesystem
#     ~~~~~~~~~~~~~~~~^^^^^^
#   File "C:\Program Files\Python313\Lib\pathlib\_local.py", line 780, in replace
#     os.replace(self, target)
#     ~~~~~~~~~~^^^^^^^^^^^^^^
# PermissionError: [WinError 5] Access is denied: 'C:\\streaming_emulator\\replay\\checkpoints\\sim001_tyre.json.tmp' -> 'C:\\streaming_emulator\\replay\\checkpoints\\sim001_tyre.json'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Program Files\Python313\Lib\threading.py", line 1041, in _bootstrap_inner
#     self.run()
#     ~~~~~~~~^^
#   File "C:\Program Files\Python313\Lib\threading.py", line 992, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\streaming_emulator\replay\service\replay_service.py", line 77, in _run_source
#     run_worker(
#     ~~~~~~~~~~^
#         source=source,
#         ^^^^^^^^^^^^^^
#     ...<8 lines>...
#         batch_interval_seconds=self.batch_interval_seconds,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "C:\streaming_emulator\replay\service\worker.py", line 211, in run_worker
#     checkpoint_store.save(
#     ~~~~~~~~~~~~~~~~~~~~~^
#         source_id=source_id,
#         ^^^^^^^^^^^^^^^^^^^^
#         last_row_index=row_index,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^
#         last_row_hash=row_hash,
#         ^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "C:\streaming_emulator\replay\service\checkpoint.py", line 69, in save
#     raise CheckpointError(
#         f"Failed to write checkpoint for {source_id}"
#     ) from e
# replay.service.checkpoint.CheckpointError: Failed to write checkpoint for sim001_tyre
# Exception in thread Thread-31 (_run_source):
# Traceback (most recent call last):
#   File "C:\streaming_emulator\replay\service\checkpoint.py", line 67, in save
#     tmp_path.replace(path)  # atomic on same filesystem
#     ~~~~~~~~~~~~~~~~^^^^^^
#   File "C:\Program Files\Python313\Lib\pathlib\_local.py", line 780, in replace
#     os.replace(self, target)
#     ~~~~~~~~~~^^^^^^^^^^^^^^
# PermissionError: [WinError 5] Access is denied: 'C:\\streaming_emulator\\replay\\checkpoints\\sim009_body.json.tmp' -> 'C:\\streaming_emulator\\replay\\checkpoints\\sim009_body.json'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Program Files\Python313\Lib\threading.py", line 1041, in _bootstrap_inner
#     self.run()
#     ~~~~~~~~^^
#   File "C:\Program Files\Python313\Lib\threading.py", line 992, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\streaming_emulator\replay\service\replay_service.py", line 77, in _run_source
#     run_worker(
#     ~~~~~~~~~~^
#         source=source,
#         ^^^^^^^^^^^^^^
#     ...<8 lines>...
#         batch_interval_seconds=self.batch_interval_seconds,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "C:\streaming_emulator\replay\service\worker.py", line 211, in run_worker
#     checkpoint_store.save(
#     ~~~~~~~~~~~~~~~~~~~~~^
#         source_id=source_id,
#         ^^^^^^^^^^^^^^^^^^^^
#         last_row_index=row_index,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^
#         last_row_hash=row_hash,
#         ^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "C:\streaming_emulator\replay\service\checkpoint.py", line 69, in save
#     raise CheckpointError(
#         f"Failed to write checkpoint for {source_id}"
#     ) from e
# replay.service.checkpoint.CheckpointError: Failed to write checkpoint for sim009_body
# Exception in thread Thread-28 (_run_source):
# Traceback (most recent call last):
#   File "C:\streaming_emulator\replay\service\checkpoint.py", line 67, in save
#     tmp_path.replace(path)  # atomic on same filesystem
#     ~~~~~~~~~~~~~~~~^^^^^^
#   File "C:\Program Files\Python313\Lib\pathlib\_local.py", line 780, in replace
#     os.replace(self, target)
#     ~~~~~~~~~~^^^^^^^^^^^^^^
# PermissionError: [WinError 5] Access is denied: 'C:\\streaming_emulator\\replay\\checkpoints\\sim008_tyre.json.tmp' -> 'C:\\streaming_emulator\\replay\\checkpoints\\sim008_tyre.json'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Program Files\Python313\Lib\threading.py", line 1041, in _bootstrap_inner
#     self.run()
#     ~~~~~~~~^^
#   File "C:\Program Files\Python313\Lib\threading.py", line 992, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\streaming_emulator\replay\service\replay_service.py", line 77, in _run_source
#     run_worker(
#     ~~~~~~~~~~^
#         source=source,
#         ^^^^^^^^^^^^^^
#     ...<8 lines>...
#         batch_interval_seconds=self.batch_interval_seconds,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "C:\streaming_emulator\replay\service\worker.py", line 211, in run_worker
#     checkpoint_store.save(
#     ~~~~~~~~~~~~~~~~~~~~~^
#         source_id=source_id,
#         ^^^^^^^^^^^^^^^^^^^^
#         last_row_index=row_index,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^
#         last_row_hash=row_hash,
#         ^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "C:\streaming_emulator\replay\service\checkpoint.py", line 69, in save
#     raise CheckpointError(
#         f"Failed to write checkpoint for {source_id}"
#     ) from e
# replay.service.checkpoint.CheckpointError: Failed to write checkpoint for sim008_tyre
# Exception in thread Thread-12 (_run_source):
# Traceback (most recent call last):
#   File "C:\streaming_emulator\replay\service\checkpoint.py", line 67, in save
#     tmp_path.replace(path)  # atomic on same filesystem
#     ~~~~~~~~~~~~~~~~^^^^^^
#   File "C:\Program Files\Python313\Lib\pathlib\_local.py", line 780, in replace
#     os.replace(self, target)
#     ~~~~~~~~~~^^^^^^^^^^^^^^
# PermissionError: [WinError 5] Access is denied: 'C:\\streaming_emulator\\replay\\checkpoints\\sim002_transmission.json.tmp' -> 'C:\\streaming_emulator\\replay\\checkpoints\\sim002_transmission.json'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Program Files\Python313\Lib\threading.py", line 1041, in _bootstrap_inner
#     self.run()
#     ~~~~~~~~^^
#   File "C:\Program Files\Python313\Lib\threading.py", line 992, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\streaming_emulator\replay\service\replay_service.py", line 77, in _run_source
#     run_worker(
#     ~~~~~~~~~~^
#         source=source,
#         ^^^^^^^^^^^^^^
#     ...<8 lines>...
#         batch_interval_seconds=self.batch_interval_seconds,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "C:\streaming_emulator\replay\service\worker.py", line 211, in run_worker
#     checkpoint_store.save(
#     ~~~~~~~~~~~~~~~~~~~~~^
#         source_id=source_id,
#         ^^^^^^^^^^^^^^^^^^^^
#         last_row_index=row_index,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^
#         last_row_hash=row_hash,
#         ^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "C:\streaming_emulator\replay\service\checkpoint.py", line 69, in save
#     raise CheckpointError(
#         f"Failed to write checkpoint for {source_id}"
#     ) from e
# replay.service.checkpoint.CheckpointError: Failed to write checkpoint for sim002_transmission
# Exception in thread Thread-34 (_run_source):
# Traceback (most recent call last):
#   File "C:\streaming_emulator\replay\service\checkpoint.py", line 67, in save
#     tmp_path.replace(path)  # atomic on same filesystem
#     ~~~~~~~~~~~~~~~~^^^^^^
#   File "C:\Program Files\Python313\Lib\pathlib\_local.py", line 780, in replace
#     os.replace(self, target)
#     ~~~~~~~~~~^^^^^^^^^^^^^^
# PermissionError: [WinError 5] Access is denied: 'C:\\streaming_emulator\\replay\\checkpoints\\sim010_engine.json.tmp' -> 'C:\\streaming_emulator\\replay\\checkpoints\\sim010_engine.json'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Program Files\Python313\Lib\threading.py", line 1041, in _bootstrap_inner
#     self.run()
#     ~~~~~~~~^^
#   File "C:\Program Files\Python313\Lib\threading.py", line 992, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\streaming_emulator\replay\service\replay_service.py", line 77, in _run_source
#     run_worker(
#     ~~~~~~~~~~^
#         source=source,
#         ^^^^^^^^^^^^^^
#     ...<8 lines>...
#         batch_interval_seconds=self.batch_interval_seconds,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "C:\streaming_emulator\replay\service\worker.py", line 211, in run_worker
#     checkpoint_store.save(
#     ~~~~~~~~~~~~~~~~~~~~~^
#         source_id=source_id,
#         ^^^^^^^^^^^^^^^^^^^^
#         last_row_index=row_index,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^
#         last_row_hash=row_hash,
#         ^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "C:\streaming_emulator\replay\service\checkpoint.py", line 69, in save
#     raise CheckpointError(
#         f"Failed to write checkpoint for {source_id}"
#     ) from e
# replay.service.checkpoint.CheckpointError: Failed to write checkpoint for sim010_engine
# Exception in thread Thread-11 (_run_source):
# Traceback (most recent call last):
#   File "C:\streaming_emulator\replay\service\checkpoint.py", line 67, in save
#     tmp_path.replace(path)  # atomic on same filesystem
#     ~~~~~~~~~~~~~~~~^^^^^^
#   File "C:\Program Files\Python313\Lib\pathlib\_local.py", line 780, in replace
#     os.replace(self, target)
#     ~~~~~~~~~~^^^^^^^^^^^^^^
# PermissionError: [WinError 5] Access is denied: 'C:\\streaming_emulator\\replay\\checkpoints\\sim002_body.json.tmp' -> 'C:\\streaming_emulator\\replay\\checkpoints\\sim002_body.json'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Program Files\Python313\Lib\threading.py", line 1041, in _bootstrap_inner
#     self.run()
#     ~~~~~~~~^^
#   File "C:\Program Files\Python313\Lib\threading.py", line 992, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\streaming_emulator\replay\service\replay_service.py", line 77, in _run_source
#     run_worker(
#     ~~~~~~~~~~^
#         source=source,
#         ^^^^^^^^^^^^^^
#     ...<8 lines>...
#         batch_interval_seconds=self.batch_interval_seconds,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "C:\streaming_emulator\replay\service\worker.py", line 211, in run_worker
#     checkpoint_store.save(
#     ~~~~~~~~~~~~~~~~~~~~~^
#         source_id=source_id,
#         ^^^^^^^^^^^^^^^^^^^^
#         last_row_index=row_index,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^
#         last_row_hash=row_hash,
#         ^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "C:\streaming_emulator\replay\service\checkpoint.py", line 69, in save
#     raise CheckpointError(
#         f"Failed to write checkpoint for {source_id}"
#     ) from e
# replay.service.checkpoint.CheckpointError: Failed to write checkpoint for sim002_body
# Exception in thread Thread-7 (_run_source):
# Traceback (most recent call last):
#   File "C:\streaming_emulator\replay\service\checkpoint.py", line 67, in save
#     tmp_path.replace(path)  # atomic on same filesystem
#     ~~~~~~~~~~~~~~~~^^^^^^
#   File "C:\Program Files\Python313\Lib\pathlib\_local.py", line 780, in replace
#     os.replace(self, target)
#     ~~~~~~~~~~^^^^^^^^^^^^^^
# PermissionError: [WinError 5] Access is denied: 'C:\\streaming_emulator\\replay\\checkpoints\\sim001_transmission.json.tmp' -> 'C:\\streaming_emulator\\replay\\checkpoints\\sim001_transmission.json'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Program Files\Python313\Lib\threading.py", line 1041, in _bootstrap_inner
#     self.run()
#     ~~~~~~~~^^
#   File "C:\Program Files\Python313\Lib\threading.py", line 992, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\streaming_emulator\replay\service\replay_service.py", line 77, in _run_source
#     run_worker(
#     ~~~~~~~~~~^
#         source=source,
#         ^^^^^^^^^^^^^^
#     ...<8 lines>...
#         batch_interval_seconds=self.batch_interval_seconds,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "C:\streaming_emulator\replay\service\worker.py", line 211, in run_worker
#     checkpoint_store.save(
#     ~~~~~~~~~~~~~~~~~~~~~^
#         source_id=source_id,
#         ^^^^^^^^^^^^^^^^^^^^
#         last_row_index=row_index,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^
#         last_row_hash=row_hash,
#         ^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "C:\streaming_emulator\replay\service\checkpoint.py", line 69, in save
#     raise CheckpointError(
#         f"Failed to write checkpoint for {source_id}"
#     ) from e
# replay.service.checkpoint.CheckpointError: Failed to write checkpoint for sim001_transmission
# Exception in thread Thread-35 (_run_source):
# Traceback (most recent call last):
#   File "C:\streaming_emulator\replay\service\checkpoint.py", line 67, in save
#     tmp_path.replace(path)  # atomic on same filesystem
#     ~~~~~~~~~~~~~~~~^^^^^^
#   File "C:\Program Files\Python313\Lib\pathlib\_local.py", line 780, in replace
#     os.replace(self, target)
#     ~~~~~~~~~~^^^^^^^^^^^^^^
# PermissionError: [WinError 5] Access is denied: 'C:\\streaming_emulator\\replay\\checkpoints\\sim010_battery.json.tmp' -> 'C:\\streaming_emulator\\replay\\checkpoints\\sim010_battery.json'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Program Files\Python313\Lib\threading.py", line 1041, in _bootstrap_inner
#     self.run()
#     ~~~~~~~~^^
#   File "C:\Program Files\Python313\Lib\threading.py", line 992, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\streaming_emulator\replay\service\replay_service.py", line 77, in _run_source
#     run_worker(
#     ~~~~~~~~~~^
#         source=source,
#         ^^^^^^^^^^^^^^
#     ...<8 lines>...
#         batch_interval_seconds=self.batch_interval_seconds,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "C:\streaming_emulator\replay\service\worker.py", line 211, in run_worker
#     checkpoint_store.save(
#     ~~~~~~~~~~~~~~~~~~~~~^
#         source_id=source_id,
#         ^^^^^^^^^^^^^^^^^^^^
#         last_row_index=row_index,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^
#         last_row_hash=row_hash,
#         ^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "C:\streaming_emulator\replay\service\checkpoint.py", line 69, in save
#     raise CheckpointError(
#         f"Failed to write checkpoint for {source_id}"
#     ) from e
# replay.service.checkpoint.CheckpointError: Failed to write checkpoint for sim010_battery
# Exception in thread Thread-30 (_run_source):
# Traceback (most recent call last):
#   File "C:\streaming_emulator\replay\service\checkpoint.py", line 67, in save
#     tmp_path.replace(path)  # atomic on same filesystem
#     ~~~~~~~~~~~~~~~~^^^^^^
#   File "C:\Program Files\Python313\Lib\pathlib\_local.py", line 780, in replace
#     os.replace(self, target)
#     ~~~~~~~~~~^^^^^^^^^^^^^^
# PermissionError: [WinError 5] Access is denied: 'C:\\streaming_emulator\\replay\\checkpoints\\sim009_battery.json.tmp' -> 'C:\\streaming_emulator\\replay\\checkpoints\\sim009_battery.json'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Program Files\Python313\Lib\threading.py", line 1041, in _bootstrap_inner
#     self.run()
#     ~~~~~~~~^^
#   File "C:\Program Files\Python313\Lib\threading.py", line 992, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\streaming_emulator\replay\service\replay_service.py", line 77, in _run_source
#     run_worker(
#     ~~~~~~~~~~^
#         source=source,
#         ^^^^^^^^^^^^^^
#     ...<8 lines>...
#         batch_interval_seconds=self.batch_interval_seconds,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "C:\streaming_emulator\replay\service\worker.py", line 211, in run_worker
#     checkpoint_store.save(
#     ~~~~~~~~~~~~~~~~~~~~~^
#         source_id=source_id,
#         ^^^^^^^^^^^^^^^^^^^^
#         last_row_index=row_index,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^
#         last_row_hash=row_hash,
#         ^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "C:\streaming_emulator\replay\service\checkpoint.py", line 69, in save
#     raise CheckpointError(
#         f"Failed to write checkpoint for {source_id}"
#     ) from e
# replay.service.checkpoint.CheckpointError: Failed to write checkpoint for sim009_battery

# %%
#service.wait()

# %%
service.stop_workers()
print("Replay workers stopped.")
# Out:
# Replay workers stopped.

# %%
service.reset(archive_dlq=True)
print("Replay state reset.")
